# %% [markdown]
# # Time Series Analysis - Tracking with MLFLow

# %% [markdown]
# ## 1. Install and Import MLFlow and Ngrok

# %% [markdown]
# ### 1.  Import & Setup MLFLow

# %%
import mlflow

# %%
# Define the MLflow storage path on local Drive
mlflow_storage_path = "/Users/lukasfichtner/Documents/Guayas_project_week3/mlflow_results"
# Set MLFlow  to log to zhe local drive directory
mlflow.set_tracking_uri(f"file:{mlflow_storage_path}")

# %%
# Set up experiment name
mlflow.set_experiment("XGB")
# Out:
# <Experiment: artifact_location='file:///Users/lukasfichtner/Documents/Guayas_project_week3/mlflow_results/464531910681999232', creation_time=1756727380633, experiment_id='464531910681999232', last_update_time=1756727380633, lifecycle_stage='active', name='XGB', tags={}>

# %%
from pyngrok import ngrok, conf
import getpass
import subprocess
import os

# %%
# Zuerst alle Prozesse auf Port 5000 beenden
subprocess.run(["pkill", "-f", "mlflow"])  # MLflow Prozesse killen
subprocess.run(["lsof", "-ti:5000", "|", "xargs", "kill", "-9"])  # Port 5000 freigeben

# %%
# Launch MLflow UI on port 5000
subprocess.Popen(["mlflow", "ui", "--backend-store-uri", mlflow_storage_path])
# Out:
# <Popen: returncode: None args: ['mlflow', 'ui', '--backend-store-uri', '/Use...>
# INFO:     Uvicorn running on http://127.0.0.1:5000 (Press CTRL+C to quit)
# INFO:     Started parent process [26918]
# INFO:     Started server process [26923]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [26922]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [26920]
# INFO:     Waiting for application startup.
# INFO:     Started server process [26921]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Application startup complete.

# %%
print("Enter your authtoken, which can be copied from https://dashboard.ngrok.com/get-started/your-authtoken")
conf.get_default().auth_token = input()
port=5000
public_url = ngrok.connect(port).public_url
print(f' * ngrok tunnel (ULR for MLFLow UI) \"{public_url}\" ')
# Out:
# Enter your authtoken, which can be copied from https://dashboard.ngrok.com/get-started/your-authtoken
#  * ngrok tunnel (ULR for MLFLow UI) "https://5403e8b87b01.ngrok-free.app"
# INFO:     127.0.0.1:52478 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52478 - "GET /ajax-api/2.0/mlflow/experiments/search?max_results=25&order_by=last_update_time+DESC HTTP/1.1" 200 OK

# %% [markdown]
# ## 2. Import Libraries and DataFrame

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from darts import TimeSeries
import requests
import xgboost as xgb
from xgboost import XGBRegressor
from xgboost import plot_importance, plot_tree
from xgboost.sklearn import XGBModel 
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, r2_score , mean_squared_error
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV

# %%
df_boost = pd.read_pickle("/Users/lukasfichtner/Documents/Guayas_project_week3/xgboost_dataset.pkl")

# %%
df_boost.head()
# Out:
#         date  store_nbr  item_nbr      id  unit_sales  lag_1  lag_7  lag_30  \
# 0 2013-01-09         24     96995  302230         2.0    0.0    0.0     0.0
# 1 2013-01-10         24     96995       0         0.0    2.0    0.0     0.0
# 2 2013-01-11         24     96995       0         0.0    0.0    0.0     0.0
# 3 2013-01-12         24     96995  419989         2.0    0.0    0.0     0.0
# 4 2013-01-13         24     96995       0         0.0    2.0    0.0     0.0
#
#    rolling_mean_7  sales_change_7d  dcoilwtico  day  month  year  day_of_week  \
# 0             0.0              0.0       93.08    9      1  2013            2
# 1             0.0              0.0       93.81   10      1  2013            3
# 2             0.0              0.0       93.60   11      1  2013            4
# 3             0.0              0.0       93.60   12      1  2013            5
# 4             0.0              0.0       93.60   13      1  2013            6
#
#    is_weekend
# 0           0
# 1           0
# 2           0
# 3           1
# 4           1
# INFO:     127.0.0.1:52897 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52900 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52897 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52901 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52902 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52899 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52898 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52901 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52900 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52897 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52906 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52907 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52909 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52908 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52906 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52910 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52911 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52907 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52909 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52908 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52913 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52913 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52915 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52914 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52917 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52918 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52916 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52913 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52915 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52914 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52920 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52920 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52922 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52920 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52923 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52921 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52924 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52922 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52925 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52920 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52926 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52926 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52929 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52927 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52929 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52928 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52931 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52926 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52930 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52927 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52932 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52937 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52935 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52932 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52933 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52936 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52934 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52937 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52935 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52932 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52941 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52944 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52946 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52945 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52944 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52946 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52945 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52941 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52942 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52943 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52951 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52951 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52952 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52953 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52954 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52956 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52955 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52951 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52952 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52953 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52957 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52957 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52958 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52961 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52959 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52962 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52957 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52960 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52958 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52961 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK

# %% [markdown]
# ## 3. XGBoost Model

# %% [markdown]
# ### 1. Train-Test Split

# %%
#Splitting the train and test data by a specified date
split_date = '2014-01-01'
train = df_boost[df_boost['date'] < split_date]
test = df_boost[df_boost['date'] > split_date]

# %%
# Define target variable (unit_sales) and features
X_train = train.drop('unit_sales', axis=1)
X_train = X_train.drop('date', axis=1)
y_train = train['unit_sales']

X_test = test.drop('unit_sales', axis=1)
X_test = X_test.drop('date', axis=1)
y_test = test['unit_sales']

# %%
# Ensure features are scaled for XGBoost (optional, but can help with convergence)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ### 2. Train XGBoost Model

# %%
# Initialize the XGBoost regressor
xgboost_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=100,
    max_depth=5,
    eta=0.1,
    enable_categorical=True
)

xgboost_model.fit(X_train, y_train)
# Out:
# INFO:     127.0.0.1:53512 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53517 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53512 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53514 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53515 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53513 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53516 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53517 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53512 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53514 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:53515 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=True, eta=0.1, eval_metric=None,
#              feature_types=None, feature_weights=None, gamma=None,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None, ...)

# %%
# Make predictions on the test set
y_pred = xgboost_model.predict(X_test)

# %% [markdown]
# ### 3. Create metrics function

# %%
def forecast_metrics(y_true, y_pred):
    #converts input data into flattened NumPy arrays
    y_true = np.asarray(y_true, dtype=float).flatten()
    y_pred = np.asarray(y_pred, dtype=float).flatten()

    # basic errors
    errors       = y_true - y_pred
    abs_errors   = np.abs(errors)
    pct_errors   = abs_errors / np.where(y_true == 0, np.nan, y_true)   # avoid ÷0

    # core statistics
    mae   = abs_errors.mean()
    bias  = errors.mean()
    rmse  = np.sqrt((errors ** 2).mean())

    # MAD of the ACTUAL series (dispersion of demand itself)
    mad   = np.abs(y_true - y_true.mean()).mean()

    # Relative MAD = MAE divided by MAD  (how big the forecast error is vs. “typical” variation)
    rmad  = mae / mad if mad else np.nan

    # Mean Absolute Percentage Error
    mape  = np.nanmean(pct_errors) * 100   # expressed in %

    return {
        "MAE" : mae,
        "Bias": bias,
        "MAD" : mad,
        "rMAD": rmad,
        "MAPE": mape,
        "RMSE": rmse
    }


metrics = forecast_metrics(y_test, y_pred)
for k, v in metrics.items():
    print(f"{k}: {v:,.2f}")
# Out:
# MAE: 0.90
# Bias: -0.21
# MAD: 5.29
# rMAD: 0.17
# MAPE: 31.89
# RMSE: 4.90

# %%
with mlflow.start_run(run_name="xgb-normal"):
    xgboost_model.fit(X_train, y_train)
    y_pred = xgboost_model.predict(X_test)
    metrics = forecast_metrics(y_test, y_pred)

    mlflow.log_param("n_estimators", 200)
    mlflow.log_param("max_depth", 5)
    mlflow.log_param("learning_rate", 0.1)
    mlflow.log_param("enable_categorical", True)
    mlflow.log_metric("MAE", metrics["MAE"])
    mlflow.log_metric("Bias", metrics["Bias"])
    mlflow.log_metric("MAD", metrics["MAD"])
    mlflow.log_metric("rMAD", metrics["rMAD"])
    mlflow.log_metric("MAPE", metrics["MAPE"])
    mlflow.log_metric("RMSE", metrics["RMSE"])

    mlflow.sklearn.log_model(xgboost_model, artifact_path="model")
# Out:
# 2025/09/02 09:06:13 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/09/02 09:06:15 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /var/folders/18/sn83f4h148vgxw6xg2nvxl7r0000gn/T/tmpq7j8_0ri/model/model.pkl, flavor: sklearn). Fall back to return ['scikit-learn==1.7.1', 'cloudpickle==3.1.1']. Set logging level to DEBUG to see the full traceback.
# 2025/09/02 09:06:15 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
# Quick plot saver
def save_forecast_plot(y_true, Y_pred, path, title="Forecast vs. Actual"):
    plt.figure(figsize=(10, 4))
    plt.plot(y_true, label='Actual', lw=2)
    plt.plot(y_pred, label='Predicted', lw=2)
    plt.title(title)
    plt.legend(); plt.tight_layout();plt.savefig(path);plt.close()

# one-stop logger for a single candidate
def log_candidate(run_name, params, y_true, y_pred, fig_name, model=None):
    with mlflow.start_run(run_name=run_name, nested=True):
        mlflow.log_params(params)
        mlflow.log_metrics(forecast_metrics(y_true, y_pred))
        save_forecast_plot(y_true, y_pred, fig_name, title=run_name)
        mlflow.log_artifact(fig_name)

        if model is None:
            return
        elif isinstance(model, XGBModel):  # covers XGBRegressor/Classifier
            mlflow.xgboost.log_model(model, name="model")
        else:
            # fallback: skip or raise
            pass

# %% [markdown]
# ### 4. Hyperparameter Tuning for XGBoost Model improvement

# %%
# Initializing the model
xgboost_model = xgb.XGBRegressor(objective='reg:squarederror')

# Define the parameter grid
param_grid = {
    'eta': [0.01, 0.05, 0.1, 0.3], # Extend learning rates
    'max_depth': [ 3, 5, 6, 7, 9], # Wider depth range
    'subsample': [ 0.7, 0.8, 0.9, 1.0], # More subsampling options
    'colsample_bytree': [ 0.7, 0.8, 0.9, 1.0], # More features samplig
    'n_estimators': [50, 100, 200, 300, 400], # Wider tree count range
    'min_child_weight': [1, 3, 5, 7], # better Control of overitting
    'gamma': [0, 0.1, 0.2, 0.3, 0.4], # Minimum loss reduction
    'lambda': [0.5, 1, 1.5, 2], # Regularization
    'alpha': [0, 0.1, 0.5, 1] # Regularization
}

# Time series split for cross-validation
tscv = TimeSeriesSplit(n_splits=5)

# Randomized search with cross-validation
random_search = RandomizedSearchCV(estimator=xgboost_model,
                                   param_distributions=param_grid,
                                   cv=tscv,
                                   n_iter=100,
                                   scoring='neg_mean_squared_error', # this is the MSE metric
                                   verbose=2
                                  )

# Fit the model and search for the best hyperparameters
random_search.fit(X_train, y_train)

# Get best hyperparameters
best_params = random_search.best_params_
print("Best Parameters for XGBoost:", best_params)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=1, max_depth=5, min_child_weight=7, n_estimators=300, subsample=0.8; total time=   2.2s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=1, max_depth=5, min_child_weight=7, n_estimators=300, subsample=0.8; total time=   3.8s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=1, max_depth=5, min_child_weight=7, n_estimators=300, subsample=0.8; total time=   5.6s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=1, max_depth=5, min_child_weight=7, n_estimators=300, subsample=0.8; total time=   7.5s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=1, max_depth=5, min_child_weight=7, n_estimators=300, subsample=0.8; total time=   9.1s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.01, gamma=0.4, lambda=1.5, max_depth=9, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   3.1s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.01, gamma=0.4, lambda=1.5, max_depth=9, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   5.4s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.01, gamma=0.4, lambda=1.5, max_depth=9, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   8.0s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.01, gamma=0.4, lambda=1.5, max_depth=9, min_child_weight=3, n_estimators=200, subsample=0.8; total time=  10.4s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.01, gamma=0.4, lambda=1.5, max_depth=9, min_child_weight=3, n_estimators=200, subsample=0.8; total time=  13.2s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=2, max_depth=9, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   1.5s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=2, max_depth=9, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   2.6s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=2, max_depth=9, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   3.8s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=2, max_depth=9, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   5.0s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=2, max_depth=9, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   6.2s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=2, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   0.8s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=2, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   1.5s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=2, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   2.2s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=2, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   3.2s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=2, max_depth=5, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   3.7s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.01, gamma=0.4, lambda=1, max_depth=3, min_child_weight=7, n_estimators=300, subsample=1.0; total time=   1.3s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.01, gamma=0.4, lambda=1, max_depth=3, min_child_weight=7, n_estimators=300, subsample=1.0; total time=   2.5s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.01, gamma=0.4, lambda=1, max_depth=3, min_child_weight=7, n_estimators=300, subsample=1.0; total time=   3.7s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.01, gamma=0.4, lambda=1, max_depth=3, min_child_weight=7, n_estimators=300, subsample=1.0; total time=   4.8s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.01, gamma=0.4, lambda=1, max_depth=3, min_child_weight=7, n_estimators=300, subsample=1.0; total time=   6.0s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.3, gamma=0.2, lambda=1, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.9; total time=   2.9s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.3, gamma=0.2, lambda=1, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.9; total time=   4.8s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.3, gamma=0.2, lambda=1, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.9; total time=   6.8s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.3, gamma=0.2, lambda=1, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.9; total time=   9.2s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.3, gamma=0.2, lambda=1, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.9; total time=  11.6s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=1.5, max_depth=6, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   0.6s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=1.5, max_depth=6, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   1.1s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=1.5, max_depth=6, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   1.6s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=1.5, max_depth=6, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   2.1s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=1.5, max_depth=6, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   2.7s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.05, gamma=0.4, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   4.2s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.05, gamma=0.4, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   7.6s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.05, gamma=0.4, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=  11.6s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.05, gamma=0.4, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=  15.8s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.05, gamma=0.4, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=  21.3s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.1, gamma=0.1, lambda=2, max_depth=9, min_child_weight=3, n_estimators=300, subsample=0.9; total time=   5.2s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.1, gamma=0.1, lambda=2, max_depth=9, min_child_weight=3, n_estimators=300, subsample=0.9; total time=   8.6s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.1, gamma=0.1, lambda=2, max_depth=9, min_child_weight=3, n_estimators=300, subsample=0.9; total time=  12.6s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.1, gamma=0.1, lambda=2, max_depth=9, min_child_weight=3, n_estimators=300, subsample=0.9; total time=  16.5s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.1, gamma=0.1, lambda=2, max_depth=9, min_child_weight=3, n_estimators=300, subsample=0.9; total time=  19.9s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=0.5, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   1.3s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=0.5, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   2.3s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=0.5, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.3s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=0.5, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=0.5, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   5.6s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=0.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   4.2s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=0.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   7.0s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=0.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  10.0s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=0.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  13.1s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=0.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  16.1s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.05, gamma=0.3, lambda=1, max_depth=7, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   0.9s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.05, gamma=0.3, lambda=1, max_depth=7, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   1.5s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.05, gamma=0.3, lambda=1, max_depth=7, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   2.2s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.05, gamma=0.3, lambda=1, max_depth=7, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   2.8s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.05, gamma=0.3, lambda=1, max_depth=7, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   3.6s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=1, max_depth=3, min_child_weight=7, n_estimators=400, subsample=1.0; total time=   2.4s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=1, max_depth=3, min_child_weight=7, n_estimators=400, subsample=1.0; total time=   4.2s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=1, max_depth=3, min_child_weight=7, n_estimators=400, subsample=1.0; total time=   6.0s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=1, max_depth=3, min_child_weight=7, n_estimators=400, subsample=1.0; total time=   8.1s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=1, max_depth=3, min_child_weight=7, n_estimators=400, subsample=1.0; total time=  10.1s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.01, gamma=0.3, lambda=2, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.7; total time=   4.6s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.01, gamma=0.3, lambda=2, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.7; total time=   8.0s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.01, gamma=0.3, lambda=2, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.7; total time=  12.0s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.01, gamma=0.3, lambda=2, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.7; total time=  15.7s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.01, gamma=0.3, lambda=2, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.7; total time=  19.8s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=1.5, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   0.8s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=1.5, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   1.5s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=1.5, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   2.1s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=1.5, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   2.7s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=1.5, max_depth=3, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   3.5s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=2, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   1.2s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=2, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   2.1s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=2, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   2.9s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=2, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.9s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=2, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   5.0s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1, max_depth=9, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   3.5s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1, max_depth=9, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   5.5s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1, max_depth=9, min_child_weight=5, n_estimators=200, subsample=0.7; total time=   7.9s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1, max_depth=9, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  10.2s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1, max_depth=9, min_child_weight=5, n_estimators=200, subsample=0.7; total time=  12.6s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.2, lambda=2, max_depth=6, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   3.9s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.2, lambda=2, max_depth=6, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   6.5s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.2, lambda=2, max_depth=6, min_child_weight=1, n_estimators=400, subsample=1.0; total time=   9.6s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.2, lambda=2, max_depth=6, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  13.4s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.2, lambda=2, max_depth=6, min_child_weight=1, n_estimators=400, subsample=1.0; total time=  17.1s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1.5, max_depth=5, min_child_weight=3, n_estimators=50, subsample=0.9; total time=   0.7s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1.5, max_depth=5, min_child_weight=3, n_estimators=50, subsample=0.9; total time=   1.2s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1.5, max_depth=5, min_child_weight=3, n_estimators=50, subsample=0.9; total time=   1.8s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1.5, max_depth=5, min_child_weight=3, n_estimators=50, subsample=0.9; total time=   2.3s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1.5, max_depth=5, min_child_weight=3, n_estimators=50, subsample=0.9; total time=   2.9s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.1, gamma=0.1, lambda=1, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.8; total time=   0.9s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.1, gamma=0.1, lambda=1, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.8; total time=   1.6s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.1, gamma=0.1, lambda=1, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.8; total time=   2.3s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.1, gamma=0.1, lambda=1, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.8; total time=   3.0s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.1, gamma=0.1, lambda=1, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.8; total time=   3.7s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.1, gamma=0.2, lambda=0.5, max_depth=6, min_child_weight=7, n_estimators=400, subsample=0.9; total time=   4.2s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.1, gamma=0.2, lambda=0.5, max_depth=6, min_child_weight=7, n_estimators=400, subsample=0.9; total time=   7.2s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.1, gamma=0.2, lambda=0.5, max_depth=6, min_child_weight=7, n_estimators=400, subsample=0.9; total time=  10.6s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.1, gamma=0.2, lambda=0.5, max_depth=6, min_child_weight=7, n_estimators=400, subsample=0.9; total time=  13.8s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.1, gamma=0.2, lambda=0.5, max_depth=6, min_child_weight=7, n_estimators=400, subsample=0.9; total time=  17.2s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.05, gamma=0.3, lambda=1.5, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   1.2s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.05, gamma=0.3, lambda=1.5, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   2.2s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.05, gamma=0.3, lambda=1.5, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   3.1s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.05, gamma=0.3, lambda=1.5, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   4.1s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.05, gamma=0.3, lambda=1.5, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.7; total time=   5.1s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.1, gamma=0.1, lambda=1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   0.8s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.1, gamma=0.1, lambda=1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   1.5s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.1, gamma=0.1, lambda=1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   2.2s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.1, gamma=0.1, lambda=1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   2.9s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.1, gamma=0.1, lambda=1, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.9; total time=   3.6s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.01, gamma=0, lambda=1, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.8; total time=   2.2s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.01, gamma=0, lambda=1, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.8; total time=   3.9s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.01, gamma=0, lambda=1, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.8; total time=   5.8s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.01, gamma=0, lambda=1, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.8; total time=   7.6s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.01, gamma=0, lambda=1, max_depth=3, min_child_weight=1, n_estimators=300, subsample=0.8; total time=   9.6s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=9, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   2.1s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=9, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   3.6s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=9, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   5.2s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=9, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   6.7s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=9, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   8.4s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.01, gamma=0.2, lambda=1, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   1.5s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.01, gamma=0.2, lambda=1, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   2.6s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.01, gamma=0.2, lambda=1, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   3.8s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.01, gamma=0.2, lambda=1, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   5.0s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.01, gamma=0.2, lambda=1, max_depth=6, min_child_weight=1, n_estimators=100, subsample=0.7; total time=   6.2s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.3, gamma=0.4, lambda=2, max_depth=3, min_child_weight=7, n_estimators=300, subsample=0.8; total time=   2.3s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.3, gamma=0.4, lambda=2, max_depth=3, min_child_weight=7, n_estimators=300, subsample=0.8; total time=   4.1s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.3, gamma=0.4, lambda=2, max_depth=3, min_child_weight=7, n_estimators=300, subsample=0.8; total time=   6.1s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.3, gamma=0.4, lambda=2, max_depth=3, min_child_weight=7, n_estimators=300, subsample=0.8; total time=   7.8s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.3, gamma=0.4, lambda=2, max_depth=3, min_child_weight=7, n_estimators=300, subsample=0.8; total time=   9.7s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.01, gamma=0.3, lambda=0.5, max_depth=7, min_child_weight=5, n_estimators=50, subsample=1.0; total time=   0.9s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.01, gamma=0.3, lambda=0.5, max_depth=7, min_child_weight=5, n_estimators=50, subsample=1.0; total time=   1.5s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.01, gamma=0.3, lambda=0.5, max_depth=7, min_child_weight=5, n_estimators=50, subsample=1.0; total time=   2.3s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.01, gamma=0.3, lambda=0.5, max_depth=7, min_child_weight=5, n_estimators=50, subsample=1.0; total time=   3.0s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.01, gamma=0.3, lambda=0.5, max_depth=7, min_child_weight=5, n_estimators=50, subsample=1.0; total time=   3.7s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.1, gamma=0, lambda=0.5, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.9; total time=   2.5s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.1, gamma=0, lambda=0.5, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.9; total time=   4.1s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.1, gamma=0, lambda=0.5, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.9; total time=   6.0s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.1, gamma=0, lambda=0.5, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.9; total time=   7.9s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.1, gamma=0, lambda=0.5, max_depth=6, min_child_weight=1, n_estimators=200, subsample=0.9; total time=   9.9s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=2, max_depth=7, min_child_weight=7, n_estimators=400, subsample=1.0; total time=   4.2s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=2, max_depth=7, min_child_weight=7, n_estimators=400, subsample=1.0; total time=   7.5s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=2, max_depth=7, min_child_weight=7, n_estimators=400, subsample=1.0; total time=  10.9s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=2, max_depth=7, min_child_weight=7, n_estimators=400, subsample=1.0; total time=  13.9s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=2, max_depth=7, min_child_weight=7, n_estimators=400, subsample=1.0; total time=  17.3s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.01, gamma=0.4, lambda=1.5, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   4.5s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.01, gamma=0.4, lambda=1.5, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   8.1s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.01, gamma=0.4, lambda=1.5, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  11.7s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.01, gamma=0.4, lambda=1.5, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  15.4s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.01, gamma=0.4, lambda=1.5, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  19.3s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=0.5, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   3.9s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=0.5, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   6.6s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=0.5, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   9.6s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=0.5, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  12.7s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=0.5, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  15.8s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0, lambda=1.5, max_depth=5, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   2.0s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0, lambda=1.5, max_depth=5, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   3.6s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0, lambda=1.5, max_depth=5, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   5.2s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0, lambda=1.5, max_depth=5, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   6.8s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0, lambda=1.5, max_depth=5, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   8.4s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0, lambda=0.5, max_depth=7, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   1.4s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0, lambda=0.5, max_depth=7, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   2.4s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0, lambda=0.5, max_depth=7, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   3.8s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0, lambda=0.5, max_depth=7, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   4.8s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0, lambda=0.5, max_depth=7, min_child_weight=7, n_estimators=100, subsample=0.7; total time=   6.2s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.01, gamma=0.2, lambda=2, max_depth=5, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   4.2s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.01, gamma=0.2, lambda=2, max_depth=5, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   7.4s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.01, gamma=0.2, lambda=2, max_depth=5, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  10.9s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.01, gamma=0.2, lambda=2, max_depth=5, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  14.6s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.01, gamma=0.2, lambda=2, max_depth=5, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  18.2s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=1.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   4.5s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=1.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   7.5s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=1.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  10.7s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=1.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  14.2s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=1.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  17.6s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.3, gamma=0.3, lambda=2, max_depth=9, min_child_weight=5, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.3, gamma=0.3, lambda=2, max_depth=9, min_child_weight=5, n_estimators=50, subsample=0.8; total time=   1.7s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.3, gamma=0.3, lambda=2, max_depth=9, min_child_weight=5, n_estimators=50, subsample=0.8; total time=   2.4s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.3, gamma=0.3, lambda=2, max_depth=9, min_child_weight=5, n_estimators=50, subsample=0.8; total time=   3.2s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.3, gamma=0.3, lambda=2, max_depth=9, min_child_weight=5, n_estimators=50, subsample=0.8; total time=   4.0s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.01, gamma=0.1, lambda=1, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   4.8s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.01, gamma=0.1, lambda=1, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   8.4s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.01, gamma=0.1, lambda=1, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  12.4s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.01, gamma=0.1, lambda=1, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  16.6s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.01, gamma=0.1, lambda=1, max_depth=6, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  21.0s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.3, gamma=0.3, lambda=0.5, max_depth=9, min_child_weight=7, n_estimators=50, subsample=0.7; total time=   1.0s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.3, gamma=0.3, lambda=0.5, max_depth=9, min_child_weight=7, n_estimators=50, subsample=0.7; total time=   1.8s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.3, gamma=0.3, lambda=0.5, max_depth=9, min_child_weight=7, n_estimators=50, subsample=0.7; total time=   2.5s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.3, gamma=0.3, lambda=0.5, max_depth=9, min_child_weight=7, n_estimators=50, subsample=0.7; total time=   3.3s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.3, gamma=0.3, lambda=0.5, max_depth=9, min_child_weight=7, n_estimators=50, subsample=0.7; total time=   4.0s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=2, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   4.9s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=2, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   8.2s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=2, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  12.3s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=2, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  15.8s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=2, max_depth=6, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  19.9s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.05, gamma=0, lambda=0.5, max_depth=9, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   2.0s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.05, gamma=0, lambda=0.5, max_depth=9, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   3.3s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.05, gamma=0, lambda=0.5, max_depth=9, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   4.8s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.05, gamma=0, lambda=0.5, max_depth=9, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   6.3s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.05, gamma=0, lambda=0.5, max_depth=9, min_child_weight=7, n_estimators=100, subsample=1.0; total time=   7.9s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.3, gamma=0, lambda=1, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.9; total time=   2.3s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.3, gamma=0, lambda=1, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.9; total time=   4.0s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.3, gamma=0, lambda=1, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.9; total time=   5.8s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.3, gamma=0, lambda=1, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.9; total time=   7.6s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.3, gamma=0, lambda=1, max_depth=3, min_child_weight=3, n_estimators=300, subsample=0.9; total time=   9.5s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=1.5, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   1.0s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=1.5, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   1.7s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=1.5, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   2.4s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=1.5, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   3.1s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.3, lambda=1.5, max_depth=3, min_child_weight=1, n_estimators=100, subsample=0.8; total time=   4.0s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.05, gamma=0.2, lambda=1, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   5.3s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.05, gamma=0.2, lambda=1, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.8; total time=   8.9s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.05, gamma=0.2, lambda=1, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  13.1s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.05, gamma=0.2, lambda=1, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  17.6s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.05, gamma=0.2, lambda=1, max_depth=7, min_child_weight=1, n_estimators=400, subsample=0.8; total time=  21.7s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.05, gamma=0.1, lambda=1.5, max_depth=9, min_child_weight=5, n_estimators=200, subsample=0.9; total time=   3.6s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.05, gamma=0.1, lambda=1.5, max_depth=9, min_child_weight=5, n_estimators=200, subsample=0.9; total time=   6.1s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.05, gamma=0.1, lambda=1.5, max_depth=9, min_child_weight=5, n_estimators=200, subsample=0.9; total time=   8.8s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.05, gamma=0.1, lambda=1.5, max_depth=9, min_child_weight=5, n_estimators=200, subsample=0.9; total time=  11.7s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.05, gamma=0.1, lambda=1.5, max_depth=9, min_child_weight=5, n_estimators=200, subsample=0.9; total time=  14.3s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=1, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.9; total time=   2.6s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=1, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.9; total time=   4.5s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=1, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.9; total time=   6.7s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=1, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.9; total time=   8.7s
# [CV] END alpha=0, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=1, max_depth=6, min_child_weight=5, n_estimators=200, subsample=0.9; total time=  11.2s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.3, gamma=0.4, lambda=0.5, max_depth=9, min_child_weight=1, n_estimators=50, subsample=0.9; total time=   1.3s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.3, gamma=0.4, lambda=0.5, max_depth=9, min_child_weight=1, n_estimators=50, subsample=0.9; total time=   2.0s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.3, gamma=0.4, lambda=0.5, max_depth=9, min_child_weight=1, n_estimators=50, subsample=0.9; total time=   2.7s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.3, gamma=0.4, lambda=0.5, max_depth=9, min_child_weight=1, n_estimators=50, subsample=0.9; total time=   3.6s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.3, gamma=0.4, lambda=0.5, max_depth=9, min_child_weight=1, n_estimators=50, subsample=0.9; total time=   4.5s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.01, gamma=0.3, lambda=2, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.8; total time=   0.9s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.01, gamma=0.3, lambda=2, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.8; total time=   1.7s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.01, gamma=0.3, lambda=2, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.8; total time=   2.5s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.01, gamma=0.3, lambda=2, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.8; total time=   3.2s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.01, gamma=0.3, lambda=2, max_depth=3, min_child_weight=7, n_estimators=100, subsample=0.8; total time=   4.1s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0.1, lambda=2, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   3.6s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0.1, lambda=2, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   6.0s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0.1, lambda=2, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   8.7s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0.1, lambda=2, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  11.8s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0.1, lambda=2, max_depth=6, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  14.6s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.3, gamma=0.3, lambda=1.5, max_depth=7, min_child_weight=5, n_estimators=400, subsample=1.0; total time=   4.8s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.3, gamma=0.3, lambda=1.5, max_depth=7, min_child_weight=5, n_estimators=400, subsample=1.0; total time=   8.1s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.3, gamma=0.3, lambda=1.5, max_depth=7, min_child_weight=5, n_estimators=400, subsample=1.0; total time=  12.0s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.3, gamma=0.3, lambda=1.5, max_depth=7, min_child_weight=5, n_estimators=400, subsample=1.0; total time=  15.6s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.3, gamma=0.3, lambda=1.5, max_depth=7, min_child_weight=5, n_estimators=400, subsample=1.0; total time=  19.3s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.3, gamma=0.1, lambda=2, max_depth=9, min_child_weight=7, n_estimators=50, subsample=0.7; total time=   1.1s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.3, gamma=0.1, lambda=2, max_depth=9, min_child_weight=7, n_estimators=50, subsample=0.7; total time=   1.8s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.3, gamma=0.1, lambda=2, max_depth=9, min_child_weight=7, n_estimators=50, subsample=0.7; total time=   2.7s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.3, gamma=0.1, lambda=2, max_depth=9, min_child_weight=7, n_estimators=50, subsample=0.7; total time=   3.5s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.3, gamma=0.1, lambda=2, max_depth=9, min_child_weight=7, n_estimators=50, subsample=0.7; total time=   4.4s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.3, gamma=0.2, lambda=1, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   1.9s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.3, gamma=0.2, lambda=1, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   3.1s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.3, gamma=0.2, lambda=1, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   4.4s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.3, gamma=0.2, lambda=1, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   5.6s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.3, gamma=0.2, lambda=1, max_depth=9, min_child_weight=3, n_estimators=100, subsample=0.9; total time=   7.0s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.1, gamma=0.3, lambda=2, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.8; total time=   3.2s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.1, gamma=0.3, lambda=2, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.8; total time=   5.5s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.1, gamma=0.3, lambda=2, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.8; total time=   8.2s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.1, gamma=0.3, lambda=2, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.8; total time=  10.7s
# [CV] END alpha=1, colsample_bytree=0.7, eta=0.1, gamma=0.3, lambda=2, max_depth=5, min_child_weight=3, n_estimators=300, subsample=0.8; total time=  13.5s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.3, lambda=1.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.8; total time=   5.0s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.3, lambda=1.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.8; total time=   8.6s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.3, lambda=1.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.8; total time=  12.7s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.3, lambda=1.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.8; total time=  16.3s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.3, lambda=1.5, max_depth=6, min_child_weight=5, n_estimators=400, subsample=0.8; total time=  20.6s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.1, gamma=0.1, lambda=0.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   5.1s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.1, gamma=0.1, lambda=0.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   8.7s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.1, gamma=0.1, lambda=0.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  12.6s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.1, gamma=0.1, lambda=0.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  16.5s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.1, gamma=0.1, lambda=0.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  20.4s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=2, max_depth=6, min_child_weight=5, n_estimators=300, subsample=1.0; total time=   3.4s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=2, max_depth=6, min_child_weight=5, n_estimators=300, subsample=1.0; total time=   6.0s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=2, max_depth=6, min_child_weight=5, n_estimators=300, subsample=1.0; total time=   8.9s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=2, max_depth=6, min_child_weight=5, n_estimators=300, subsample=1.0; total time=  11.6s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=2, max_depth=6, min_child_weight=5, n_estimators=300, subsample=1.0; total time=  15.0s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.05, gamma=0, lambda=0.5, max_depth=9, min_child_weight=5, n_estimators=400, subsample=0.7; total time=   7.4s
# INFO:     127.0.0.1:55049 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%25f2a9134f59344ab784bb6423882e41a3%25%22 HTTP/1.1" 200 OK
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.05, gamma=0, lambda=0.5, max_depth=9, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  12.6s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.05, gamma=0, lambda=0.5, max_depth=9, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  18.7s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.05, gamma=0, lambda=0.5, max_depth=9, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  23.9s
# [CV] END alpha=0, colsample_bytree=0.7, eta=0.05, gamma=0, lambda=0.5, max_depth=9, min_child_weight=5, n_estimators=400, subsample=0.7; total time=  30.0s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   1.2s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   2.2s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   3.4s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   4.4s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.01, gamma=0, lambda=1, max_depth=5, min_child_weight=3, n_estimators=100, subsample=0.8; total time=   5.6s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.2, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   5.3s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.2, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   8.4s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.2, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  12.2s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.2, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  15.6s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.2, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  19.4s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.1, lambda=1.5, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   2.7s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.1, lambda=1.5, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   4.6s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.1, lambda=1.5, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   6.8s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.1, lambda=1.5, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   8.9s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.1, lambda=1.5, max_depth=6, min_child_weight=3, n_estimators=200, subsample=0.8; total time=  11.3s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.05, gamma=0.3, lambda=1, max_depth=7, min_child_weight=3, n_estimators=300, subsample=0.7; total time=   4.5s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.05, gamma=0.3, lambda=1, max_depth=7, min_child_weight=3, n_estimators=300, subsample=0.7; total time=   7.4s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.05, gamma=0.3, lambda=1, max_depth=7, min_child_weight=3, n_estimators=300, subsample=0.7; total time=  11.1s
# [CV] END alpha=0.1, colsample_bytree=0.7, eta=0.05, gamma=0.3, lambda=1, max_depth=7, min_child_weight=3, n_estimators=300, subsample=0.7; total time=  14.9s
# ...
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.1, gamma=0.4, lambda=2, max_depth=6, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   0.6s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.1, gamma=0.4, lambda=2, max_depth=6, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   1.0s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.1, gamma=0.4, lambda=2, max_depth=6, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   1.5s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.1, gamma=0.4, lambda=2, max_depth=6, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   1.9s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.1, gamma=0.4, lambda=2, max_depth=6, min_child_weight=7, n_estimators=50, subsample=0.8; total time=   2.4s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1, max_depth=9, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   1.4s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1, max_depth=9, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   2.4s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1, max_depth=9, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   3.4s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1, max_depth=9, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   4.4s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.1, gamma=0.4, lambda=1, max_depth=9, min_child_weight=7, n_estimators=100, subsample=0.9; total time=   5.5s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.05, gamma=0.3, lambda=1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   0.9s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.05, gamma=0.3, lambda=1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   1.7s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.05, gamma=0.3, lambda=1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   2.5s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.05, gamma=0.3, lambda=1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   3.3s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.05, gamma=0.3, lambda=1, max_depth=3, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   4.1s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=1, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   2.7s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=1, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   4.8s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=1, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   7.1s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=1, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=   9.3s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.05, gamma=0.4, lambda=1, max_depth=5, min_child_weight=7, n_estimators=400, subsample=0.7; total time=  11.7s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.01, gamma=0.4, lambda=0.5, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.7; total time=   2.0s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.01, gamma=0.4, lambda=0.5, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.7; total time=   3.7s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.01, gamma=0.4, lambda=0.5, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.7; total time=   5.4s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.01, gamma=0.4, lambda=0.5, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.7; total time=   7.2s
# [CV] END alpha=0.1, colsample_bytree=1.0, eta=0.01, gamma=0.4, lambda=0.5, max_depth=3, min_child_weight=1, n_estimators=400, subsample=0.7; total time=   9.0s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.05, gamma=0.3, lambda=2, max_depth=5, min_child_weight=7, n_estimators=50, subsample=0.9; total time=   0.5s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.05, gamma=0.3, lambda=2, max_depth=5, min_child_weight=7, n_estimators=50, subsample=0.9; total time=   0.9s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.05, gamma=0.3, lambda=2, max_depth=5, min_child_weight=7, n_estimators=50, subsample=0.9; total time=   1.3s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.05, gamma=0.3, lambda=2, max_depth=5, min_child_weight=7, n_estimators=50, subsample=0.9; total time=   1.7s
# [CV] END alpha=1, colsample_bytree=1.0, eta=0.05, gamma=0.3, lambda=2, max_depth=5, min_child_weight=7, n_estimators=50, subsample=0.9; total time=   2.1s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   1.3s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   2.3s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   3.4s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   4.5s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=5, min_child_weight=3, n_estimators=200, subsample=1.0; total time=   5.7s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=2, max_depth=9, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   4.6s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=2, max_depth=9, min_child_weight=3, n_estimators=400, subsample=0.9; total time=   7.5s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=2, max_depth=9, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  10.8s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=2, max_depth=9, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  14.0s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.1, gamma=0.1, lambda=2, max_depth=9, min_child_weight=3, n_estimators=400, subsample=0.9; total time=  17.5s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0.2, lambda=0.5, max_depth=3, min_child_weight=5, n_estimators=50, subsample=0.7; total time=   0.4s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0.2, lambda=0.5, max_depth=3, min_child_weight=5, n_estimators=50, subsample=0.7; total time=   0.8s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0.2, lambda=0.5, max_depth=3, min_child_weight=5, n_estimators=50, subsample=0.7; total time=   1.1s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0.2, lambda=0.5, max_depth=3, min_child_weight=5, n_estimators=50, subsample=0.7; total time=   1.5s
# [CV] END alpha=0.5, colsample_bytree=1.0, eta=0.1, gamma=0.2, lambda=0.5, max_depth=3, min_child_weight=5, n_estimators=50, subsample=0.7; total time=   1.8s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=5, min_child_weight=7, n_estimators=300, subsample=0.9; total time=   2.0s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=5, min_child_weight=7, n_estimators=300, subsample=0.9; total time=   3.6s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=5, min_child_weight=7, n_estimators=300, subsample=0.9; total time=   5.3s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=5, min_child_weight=7, n_estimators=300, subsample=0.9; total time=   7.0s
# [CV] END alpha=0.1, colsample_bytree=0.8, eta=0.05, gamma=0.2, lambda=0.5, max_depth=5, min_child_weight=7, n_estimators=300, subsample=0.9; total time=   8.8s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.3, lambda=1, max_depth=9, min_child_weight=1, n_estimators=300, subsample=0.9; total time=   3.6s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.3, lambda=1, max_depth=9, min_child_weight=1, n_estimators=300, subsample=0.9; total time=   5.8s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.3, lambda=1, max_depth=9, min_child_weight=1, n_estimators=300, subsample=0.9; total time=   8.4s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.3, lambda=1, max_depth=9, min_child_weight=1, n_estimators=300, subsample=0.9; total time=  11.8s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.05, gamma=0.3, lambda=1, max_depth=9, min_child_weight=1, n_estimators=300, subsample=0.9; total time=  14.2s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=1, max_depth=7, min_child_weight=7, n_estimators=400, subsample=0.9; total time=   3.3s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=1, max_depth=7, min_child_weight=7, n_estimators=400, subsample=0.9; total time=   5.4s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=1, max_depth=7, min_child_weight=7, n_estimators=400, subsample=0.9; total time=   7.9s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=1, max_depth=7, min_child_weight=7, n_estimators=400, subsample=0.9; total time=  10.3s
# [CV] END alpha=0, colsample_bytree=1.0, eta=0.3, gamma=0.4, lambda=1, max_depth=7, min_child_weight=7, n_estimators=400, subsample=0.9; total time=  12.7s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.1, gamma=0.3, lambda=0.5, max_depth=6, min_child_weight=5, n_estimators=50, subsample=0.7; total time=   0.6s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.1, gamma=0.3, lambda=0.5, max_depth=6, min_child_weight=5, n_estimators=50, subsample=0.7; total time=   1.0s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.1, gamma=0.3, lambda=0.5, max_depth=6, min_child_weight=5, n_estimators=50, subsample=0.7; total time=   1.5s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.1, gamma=0.3, lambda=0.5, max_depth=6, min_child_weight=5, n_estimators=50, subsample=0.7; total time=   2.0s
# [CV] END alpha=1, colsample_bytree=0.8, eta=0.1, gamma=0.3, lambda=0.5, max_depth=6, min_child_weight=5, n_estimators=50, subsample=0.7; total time=   2.5s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.01, gamma=0.3, lambda=1, max_depth=7, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   2.1s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.01, gamma=0.3, lambda=1, max_depth=7, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   3.6s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.01, gamma=0.3, lambda=1, max_depth=7, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   5.3s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.01, gamma=0.3, lambda=1, max_depth=7, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   7.0s
# [CV] END alpha=0.1, colsample_bytree=0.9, eta=0.01, gamma=0.3, lambda=1, max_depth=7, min_child_weight=7, n_estimators=200, subsample=0.8; total time=   8.9s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.2, lambda=0.5, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   0.6s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.2, lambda=0.5, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   1.2s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.2, lambda=0.5, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   1.7s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.2, lambda=0.5, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   2.3s
# [CV] END alpha=0, colsample_bytree=0.8, eta=0.1, gamma=0.2, lambda=0.5, max_depth=3, min_child_weight=5, n_estimators=100, subsample=0.7; total time=   2.8s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.3, gamma=0.3, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=50, subsample=0.8; total time=   0.6s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.3, gamma=0.3, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=50, subsample=0.8; total time=   1.1s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.3, gamma=0.3, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=50, subsample=0.8; total time=   1.6s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.3, gamma=0.3, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=50, subsample=0.8; total time=   2.1s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.3, gamma=0.3, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=50, subsample=0.8; total time=   2.6s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.01, gamma=0.3, lambda=0.5, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   3.1s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.01, gamma=0.3, lambda=0.5, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   5.4s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.01, gamma=0.3, lambda=0.5, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7; total time=   8.0s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.01, gamma=0.3, lambda=0.5, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  10.7s
# [CV] END alpha=0.5, colsample_bytree=0.7, eta=0.01, gamma=0.3, lambda=0.5, max_depth=7, min_child_weight=1, n_estimators=300, subsample=0.7; total time=  13.4s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=2, max_depth=9, min_child_weight=1, n_estimators=50, subsample=0.7; total time=   0.8s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=2, max_depth=9, min_child_weight=1, n_estimators=50, subsample=0.7; total time=   1.4s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=2, max_depth=9, min_child_weight=1, n_estimators=50, subsample=0.7; total time=   2.1s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=2, max_depth=9, min_child_weight=1, n_estimators=50, subsample=0.7; total time=   2.7s
# [CV] END alpha=0.5, colsample_bytree=0.9, eta=0.01, gamma=0.2, lambda=2, max_depth=9, min_child_weight=1, n_estimators=50, subsample=0.7; total time=   3.5s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.4, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   3.5s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.4, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   5.7s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.4, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=   8.2s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.4, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=  10.9s
# [CV] END alpha=1, colsample_bytree=0.9, eta=0.3, gamma=0.4, lambda=1.5, max_depth=7, min_child_weight=3, n_estimators=400, subsample=0.8; total time=  13.3s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=0.5, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   1.0s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=0.5, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   2.0s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=0.5, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   2.9s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=0.5, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   3.8s
# [CV] END alpha=0.5, colsample_bytree=0.8, eta=0.3, gamma=0.4, lambda=0.5, max_depth=3, min_child_weight=3, n_estimators=200, subsample=0.8; total time=   4.8s
# Best Parameters for XGBoost: {'subsample': 1.0, 'n_estimators': 200, 'min_child_weight': 3, 'max_depth': 5, 'lambda': 0.5, 'gamma': 0.2, 'eta': 0.05, 'colsample_bytree': 0.8, 'alpha': 0.1}

# %%
def forecast_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true, y_pred)
    bias = np.mean(y_pred - y_true)
    
    # Calculate MAPE (Mean Absolute Percentage Error)
    # Avoid division by zero
    mask = y_true != 0
    mape = np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask])) * 100 if np.any(mask) else np.nan
    
    # Calculate MAD (Median Absolute Deviation) and rMAD (relative MAD)
    mad = np.median(np.abs(y_pred - y_true))
    rmad = mad / np.median(np.abs(y_true)) if np.median(np.abs(y_true)) != 0 else np.nan
    
    return {
        'MAE': mae,
        'MSE': mse,
        'RMSE': rmse,
        'R2': r2,
        'Bias': bias,
        'MAPE': mape,
        'MAD': mad,
        'rMAD': rmad
    }

# %%
# Start a PARENT MLflow run to group all candidate models from this search
with mlflow.start_run(run_name="XGB_hyperparam_search"):

    # Log all CV results, not individual test evaluations
    mlflow.log_params(best_params)
    #mlflow.log_metric("best_cv_score", -random_search.best_score_)  # Convert back from negative MSE

    # ONLY NOW train the final model on full training data
    final_model = XGBRegressor(**best_params, random_state=42)
    final_model.fit(X_train, y_train)

    # FINALLY evaluate on test set (only once!)
    y_pred = final_model.predict(X_test)

    # Log the final model evaluation
    log_candidate(
        run_name="xgb_final_model",
        params={"model_type": "XGB", **best_params},
        y_true=y_test,
        y_pred=y_pred,
        fig_name="xgb_final_forecast.png",
        model=final_model
    )
# Out:
# INFO:     127.0.0.1:55076 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%25f2a9134f59344ab784bb6423882e41a3%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55076 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%25f2a9134f59344ab784bb6423882e41a3%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55076 - "GET /ajax-api/2.0/mlflow/experiments/search?max_results=25&order_by=last_update_time+DESC HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55076 - "POST /ajax-api/2.0/mlflow/experiments/search-datasets HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55078 - "GET /ajax-api/2.0/mlflow/gateway-proxy?gateway_path=api%2F2.0%2Fendpoints%2F HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55080 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55079 - "POST /ajax-api/2.0/mlflow/logged-models/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55080 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55079 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55078 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55081 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55080 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55082 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55076 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55078 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55080 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55079 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55081 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55082 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55078 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55080 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55076 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# /Users/lukasfichtner/Documents/Guayas_project_week3/.venv/lib/python3.13/site-packages/xgboost/sklearn.py:1028: UserWarning: [11:17:21] WARNING: /Users/runner/work/xgboost/xgboost/src/c_api/c_api.cc:1427: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats.
#   self.get_booster().save_model(fname)
# 2025/09/02 11:17:23 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /var/folders/18/sn83f4h148vgxw6xg2nvxl7r0000gn/T/tmpd7i9ta81/model, flavor: xgboost). Fall back to return ['xgboost==3.0.4']. Set logging level to DEBUG to see the full traceback.
# 2025/09/02 11:17:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# INFO:     127.0.0.1:55089 - "POST /ajax-api/2.0/mlflow/runs/delete HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55089 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55089 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55089 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55091 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55094 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55090 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55093 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55089 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55091 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55095 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55094 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55090 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55093 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55089 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55095 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55094 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55091 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55090 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55096 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55096 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55099 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55098 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55096 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55097 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55100 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55099 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55101 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55096 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55099 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55097 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55096 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55098 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55100 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55099 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55101 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55108 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55108 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55111 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55110 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55109 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55112 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55108 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55111 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55113 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55112 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55110 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55109 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55111 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55112 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55113 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55108 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55110 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55114 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55114 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55117 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55119 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55115 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55117 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55119 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55116 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55114 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55119 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55117 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55118 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55119 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55117 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55115 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55116 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55114 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55121 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55121 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55124 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55125 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55122 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55124 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55125 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55126 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55123 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55121 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55124 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55125 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55124 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55122 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55126 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55123 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55121 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55127 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55127 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55128 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55127 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55128 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55129 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55130 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55131 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55127 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55132 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55128 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55127 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55128 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55130 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55129 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55131 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55132 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55133 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55133 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55134 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55133 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55137 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55136 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55134 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55135 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55133 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55138 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55134 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55133 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55134 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55137 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55135 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55136 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55138 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55139 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55139 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55140 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55139 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55140 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55141 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55139 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55144 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55143 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55142 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55140 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55139 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55140 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55141 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55144 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55143 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55142 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55145 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55145 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55148 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55150 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55148 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55150 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55146 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55148 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55150 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55147 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55149 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55148 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55150 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55145 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55146 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55147 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55149 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55155 - "POST /ajax-api/2.0/mlflow/runs/search HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55159 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=74bb18fc13204299b0fafe61cf4a46fd HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55155 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=496b3c4a883f4c8da252703cf96cb34a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55157 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=1a48865e291f4f73afe74902a7f0ae3f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55159 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=ab65122ac1154fe1a831a6112e268b4a HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55160 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=02d33ca3e04249b49a2da6eb9bcfc7a9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55158 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=251f1bd524f843639cf403017d746d8c HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55159 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=36852558ad374d3b92268592122b928b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55156 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=47164badbc0848f8a6fdf6516f432782 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55157 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=3d4fe2979d234f0298dae31e5eec6532 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55155 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=a1e34909b93a46fb93ead1848d5d0b8d HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55159 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=18137aa70ae1422cbdd72b89b30c034f HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55157 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=89ebd89280d746c4b4bf5cdd1a3d03a1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55160 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=5c81ae8e05f744d794d51bbfaff608e1 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55155 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=8ae4f5cbfc5e418f88a863f053c20cf2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55158 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=b29876393f284328a10bfbb1d52712d9 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55156 - "GET /ajax-api/2.0/mlflow/runs/get?run_id=4d326e7535724c1198a915baeb38375b HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55165 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=tags.%60mlflow.prompt.is_prompt%60+%3D+%27true%27+AND+tags.%60mlflow.prompt.run_ids%60+ILIKE+%22%25f2a9134f59344ab784bb6423882e41a3%25%22 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:55166 - "GET /ajax-api/2.0/mlflow/model-versions/search?filter=run_id%3D%27f2a9134f59344ab784bb6423882e41a3%27 HTTP/1.1" 200 OK
